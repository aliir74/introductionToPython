# %% [markdown]
# # Function
#
#
# 1. Reduced Coding Time
# 2. Reduced Debugging Time
# 3. Maintenance Effects
# 4. ...
#
#
# ## Define Function
#
# ```python
#
# def function_name(arg1, arg2):
#     "Function Documents"
#     statement1
#     statement2
#     ...
#     statementN
#     return [expression]
# ```
#
# ## Call Function
#
# ```python
#
# function_name(a, b)
# ```

# %%
def zojiyat(number):
    if(number % 2 == 0):
        print("zoj")
    else:
        print("fard")

a = int(input())
zojiyat(a)
print("END")
# Out:
# 777
# fard
# END

# %%
def isprime(a):
    cnt = 0
    for i in range(1, a+1):
        if(a % i == 0):
            #cnt = cnt + 1
            cnt += 1
    if(cnt == 2):
        print(a, "is prime!")
    else:
        print(a, 'isnt prime!')

a = int(input())
for i in range(1, a+1):
    isprime(i)
# Out:
# 10
# 1 isnt prime!
# 2 is prime!
# 3 is prime!
# 4 isnt prime!
# 5 is prime!
# 6 isnt prime!
# 7 is prime!
# 8 isnt prime!
# 9 isnt prime!
# 10 isnt prime!

# %%
def zojiyat(number):
    if(number % 2 == 0):
        return True
    else:
        return False
    print(100000000)

a = int(input())
b = zojiyat(a)
if(b == True):
    print(a, "zoj")
else:
    print(a, "fard")
print("END")
# Out:
# 9873
# 9873 fard
# END

# %% [markdown]
# ## The return Statement
#
# ```python
#
# def test(a, b):
#     print(a+b)
#
# c = test(1, 2)
# print(c)
# ```
# > None
#
# ```python
#
# def test(a, b):
#     print(a+b)
#     return
#
# c = test(1, 2)
# print(c)
# ```
# > None
#
# ```python
#
# def test(a, b):
#     print(a+b)
#     return a+b
#
# c = test(1, 2)
# print(c)
# ```
# > 3
#
# ```python
#
# def test(a, b):
#     print(a+b)
#     return a+b, a-b, a*b, a//b
#
# c = test(1, 2)
# print(c)
# ```
# > (3, -1, 2, 0)

# %%
def isprime(a):
    cnt = 0
    for i in range(1, a+1):
        if(a % i == 0):
            #cnt = cnt + 1
            cnt += 1
    if(cnt == 2):
        return True
    else:
        return False
        
def isprime2(a):
    if(a == 1):
        return False
    for i in range(2, a):
        if(a % i == 0):
            return False
    return True
           
a = int(input())
for i in range(1, a+1):
    if(isprime2(i)):
        print(i)
# Out:
# 10
# 2
# 3
# 5
# 7

# %%
def isOk(num):
    if num[4]+num[2] == 14 and \
        num[0] == 2*num[1]-1 and \
        num[3] == num[1]+1 and \
        num[2]+num[1] == 10 and \
        sumDigits(num) == 30:
            return True
    return False

def sumDigits(num2):
    ans = 0
    for i in num2:
        ans = ans + i
    return ans

for i in range(10**4, 10**5):
    s = str(i)
    l = [int(k) for k in s]
    #l.reverse()
    if(isOk(l)):
        print(i)
        
#۷۴۶۵۸
# Out:
# 74658

# %% [markdown]
# > Practice

# %%
def test(l):
    l.append(10)
    print('l: ', l)

x = [1, 2, 3]
print('x before function: ', x)
test(x)
print('x: ', x)
# Out:
# x before function:  [1, 2, 3]
# l:  [1, 2, 3, 10]
# x:  [1, 2, 3, 10]

# %% [markdown]
# ## Pass by Reference vs Value
#
#
# ### Mutable Object ( List, Dictionary, ... )
#
# ```python
#
# def test(l):
#     l.append(10)
#     print('l: ', l)
#
# x = [1, 2, 3]
# print('x before function: ', x)
# test(x)
# print('x: ', x)
# ```
#
# ```python
#
# def test(l):
#     l = ['a', 'b', 'c']
#     print('l: ', l)
#
# x = [1, 2, 3]
# print('x before function: ', x)
# test(x)
# print('x: ', x)
# ```

# %%
# test mutable object pass
def test(d):
    d['key3'] = 3
    print('in function:', d)
    
n = {'key1': 1, 'key2': 2}
print(n)
test(n)
print(n)
# Out:
# {'key1': 1, 'key2': 2}
# in function: {'key1': 1, 'key3': 3, 'key2': 2}
# {'key1': 1, 'key3': 3, 'key2': 2}

# %% [markdown]
# ### Immutable Object ( Variable, String , ... )
#
# ```python
#
# def test(s):
#     s[0] = 'a'
#     print('s: ', s)
#
# x = 'hi'
# print('x before function: ', x)
# test(x)
# print('x: ', x)
# ```
#
# ```python
#
# def test(s):
#     s = 'bye'
#     print('s: ', s)
#
# x = 'hi'
# print('x before function: ', x)
# test(x)
# print('x: ', x)
# ```

# %%
# test immutable object pass

def test(s):
    s = 'bye'
    print('s: ', s)

x = 'hi'
print('x before function: ', x)
test(x)
print('x: ', x)
# Out:
# x before function:  hi
# s:  bye
# x:  hi

# %%
def test(s,x=1000):
    print(s,x)

test(10, 200)

print(10, 2, 3, 4 )
# Out:
# ------------------------------------------------
# TypeError      Traceback (most recent call last)
# <ipython-input-18-60883b21dceb> in <module>()
#       2     print(s,x)
#       3
# ----> 4 test(10, 200,3 )
#       5
#       6 print(10, 2, 3, 4 )
#
# TypeError: test() takes from 1 to 2 positional arguments but 3 were given

# %% [markdown]
# ## Function Arguments
#
# ### Required Arguments
#
# ```python
#
# def test(s):
#     print(s)
#
# test()
# ```
#
# ### Keyword Arguments
#
# ```python
#
# def test(name, age):
#     print("name: ", name)
#     print("age: ", age)
#
# test('ali', 22)
#
# test(age=10, name="ali")
# ```
#
# ### Default Arguments
#
# ```python
#
# def test(name, age=10):
#     print("name: ", name)
#     print("age: ", age)
#
# test('ali')
#
# test('ali', 10)
# ```
#
# ### Variable-length Arguments
#
# ```python
#
# def test(name, *vartuple):
#     print('Name: ', name)
#
#     for i in vartuple:
#         print(i)
#
# test('ali', 1, 2, 3, 4, 5, 6, 'salam', 'lka')
# ```
# > An asterisk (*) is placed before the variable name that holds the values of all nonkeyword variable arguments.
# >
# > This tuple remains empty if no additional arguments are specified during the function call.

# %%
def test(name, age, *vartuple):
    print('Name: ', name)
    print('Age:' , age)
    
    for i in vartuple:
        print(i)
    
test('ali', 10, 'a', 'kdajhf', 29)
# Out:
# Name:  ali
# Age: 10
# a
# kdajhf
# 29

# %% [markdown]
# ## Scope of Variables
#
# All variables in a program may not be accessible at all locations in that program. This depends on where you have declared a variable.
#
# ### Global vs. Local variables
#
#
# > Read global variable in function
# >
# > But, write global variable in function?

# %%
def test():
    global b, a
    b = 10
    a = 20
    print('function: ',b, a)
    
b = 1000
a = 20000
test()
print(b, a)
# Out:
# function:  10 20
# 10 20

# %%
def test():
    print(10)
    print(1000)
    a = a*10
    print(b)
    
a = 10
test()
# Out:
# 10
# 1000
# 20

# %%
def test():
    a = 20
    print(a)
    
a = 10
test()
print(a)

# %% [markdown]
# #### Global Keyword
#
# ```python
#
# def test():
#     global a
#
#     a = 20
#
# a = 10
# test()
# print(a)
# ```

# %%
def test():
    a = 20
    print('function a:',a)
    
a = 10
test()
print('main a:', a)

# %%
import BeautifulSoup
print(math.sqrt(10))
# Out:
# ------------------------------------------------
# ImportError    Traceback (most recent call last)
# <ipython-input-50-7b5bbedd6224> in <module>()
# ----> 1 import BeautifulSoup
#       2 print(math.sqrt(10))
#
# ImportError: No module named 'BeautifulSoup'

# %% [markdown]
# # Module
#
# ```python
# import module1[, module2[,... moduleN]
# ```
#
# ```python
# from module1 import func1
#
# from moodule1 import *
# ```
#
#
# ## Executing Modules as Scripts
#
# ```python
#
# def fib(n): # return Fibonacci series up to n
#    result = []
#    a, b = 0, 1
#    while b < n:
#       result.append(b)
#       a, b = b, a + b
#    return result
# if __name__ == "__main__":
#    f = fib(100)
#    print(f)
# ```
#
# ## Locating Modules
#
# 1. The current directory.
#
# 2. If the module is not found, Python then searches each directory in the shell variable PYTHONPATH.
#
# 3. If all else fails, Python checks the default path. On UNIX, this default path is normally /usr/local/lib/python3/.
#
# > The module search path is stored in the system module sys as the sys.path variable.
#
# ### Set Pythonpath in windows
#
# `My Computer > Properties > Advanced System Settings > Environment Variables >`
#
# ## The dir( ) Function
#
# The dir() built-in function returns a sorted list of strings containing the names defined by a module.

# %%
import sys

print(sys.path)
# Out:
# ['', '/usr/lib/python35.zip', '/usr/lib/python3.5', '/usr/lib/python3.5/plat-x86_64-linux-gnu', '/usr/lib/python3.5/lib-dynload', '/home/ali/.local/lib/python3.5/site-packages', '/usr/local/lib/python3.5/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.5/dist-packages/IPython/extensions', '/home/ali/.ipython']

# %%
import math

content = dir(math)

print (content)
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'trunc']

# %%
f = open('/home/ali/Desktop/file/aaa.txt', 'w')
f.write('aaaaaaaaaaaa')
f.close()

# %% [markdown]
# # File
#
#
# ## Open file
#
# ```python
#
# file_object = open(file_name [, access_mode][, buffering])
# ```
#
# | Mode | Description |
# | :---: | :--- |
# | r | Opens a file for reading only. The file pointer is placed at the beginning of the file. This is the default mode.|
# | r+ | Opens a file for both reading and writing. The file pointer placed at the beginning of the file. |
# | w | Opens a file for writing only. Overwrites the file if the file exists. If the file does not exist, creates a new file for writing. |
# | a | Opens a file for appending. The file pointer is at the end of the file if the file exists. That is, the file is in the append mode. If the file does not exist, it creates a new file for writing. |
#
# ## The file Object Attributes
#
# `file.closed`
# > Returns true if file is closed, false otherwise.
#
# `file.mode`
# > Returns access mode with which file was opened.
#
# `file.name`
# > Returns name of the file.
#
#
# ## The close() Method
#
# The close() method of a file object flushes any unwritten information and closes the file object, after which no more writing can be done.
#
# > Python automatically closes a file when the reference object of a file is reassigned to another file.
#
# ## Reading and Writing Files
#
# ### The write() Method
#
# The write() method writes any _**string**_ to an open file
#
# > The write() method does not add a newline character ('\n') to the end of the string
#
# ```python
#
# fileObject.write(string)
# ```
#
# ### The read() Method
#
# The read() method reads a _**string**_ from an open file.
#
# ```python
#
# fileObject.read([count])
# ```
#
# > Here, passed parameter is the number of bytes to be read from the opened file. This method starts reading from the beginning of the file and if count is missing, then it tries to read as much as possible, maybe until the end of file.

# %%
# Close file to write

f = open('/home/ali/Desktop/file/ali.txt', 'r+')
print(f.tell())
f.seek(5)
print(f.tell())
s2 = f.write('ali')
print(f.tell())
f.close()
f = open('/home/ali/Desktop/file/ali.txt', 'r')
print(f.tell())
print(f.read())
print(f.tell())
# Out:
# 0
# 5
# 8
# 0
# ali23ali7329847
# 15

# %%
import os

print(os.getcwd())

os.chdir('/home/ali/Desktop/file/iman/ali')
print(os.getcwd())
os.mkdir('ali')
# Out:
# /home/ali/Desktop/file/iman
# /home/ali/Desktop/file/iman/ali

# %% [markdown]
# ### File Positions
#
# ```python
# f = open('test')
# print(f.tell())
# ```
# > The _tell()_ method tells you the current position within the file
#
# ```python
# f.seek(index)
# ```
# > The _seek(index)_ method changes the current file position.
#
# ## Renaming and Deleting Files
#
# ```python
# import os
#
# os.rename(current_file_name, new_file_name)
#
# os.remove(file_name)
# ```
#
# ## Directories in Python
#
# ### The mkdir() and chdir() Method
#
# ```python
# os.mkdir('newdir')
#
# os.chdir('newdir')
# ```
# > Change currnet directory
#
# ```python
# os.getcwd()
# ```
# > The getcwd() method displays the current working directory.
#
# ```python
# os.rmdir('dirname')
# ```
# > The rmdir() method deletes the directory, which is passed as an argument in the method.

# %% [markdown]
# # Errors and Exceptions
#
# ## Syntax Errors
#
# Syntax errors, also known as parsing errors, are perhaps the most common kind of complaint you get while you are still learning Python:
#
# ```python
# >>> while True print('Hello world')
#   File "<stdin>", line 1
#     while True print('Hello world')
#                    ^
# SyntaxError: invalid syntax
# ```
#
# ## Exceptions
#
# Even if a statement or expression is syntactically correct, it may cause an error when an attempt is made to execute it.
#
# ```python
# >>> 10 * (1/0)
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ZeroDivisionError: division by zero
#
# >>> 4 + spam*3
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# NameError: name 'spam' is not defined
#
# >>> '2' + 2
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# TypeError: Can't convert 'int' object to str implicitly
# ```
#
# ### Handling Exceptions¶
#
# ```python
# if(True):
#     try:
#         x = int(input("Please enter a number: "))
#     except ValueError:
#         print("Oops!  That was no valid number.")
# ```
# ---
# ```python
# try:
#     statement
# except (RuntimeError, TypeError, NameError):
#     pass
# ```
# ---
# ```python
# try:
#     f = open('myfile.txt')
#     s = f.readline()
#     i = int(s)
# except OSError as err:
#     print("OS error: ", (err))
# except ValueError:
#     print("Could not convert data to an integer.")
# except:
#     print("Unexpected error!")
# ```
# ---
# ```python
# try:
#     f = open(s, 'r')
# except IOError:
#     print('cannot open', s)
# else:
#     print(s, 'has', len(f.readlines()), 'lines')
#     f.close()
# ```
# > Why else?
#
# ---
#
# ```python
# try:
#     result = x / y
# except ZeroDivisionError:
#     print("division by zero!")
# finally:
#     print("executing finally clause")
# ```

# %%
x = int(input())

while(True):
    try:
        x = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops!  That was no valid number.")
print("END)")
# Out:
# ljasd
# ------------------------------------------------
# ValueError     Traceback (most recent call last)
# <ipython-input-101-b5df295af023> in <module>()
# ----> 1 x = int(input())
#       2
#       3 while(True):
#       4     try:
#       5         x = int(input("Please enter a number: "))
#
# ValueError: invalid literal for int() with base 10: 'ljasd'

# %% [markdown]
# # References
#
# 1. https://www.tutorialspoint.com/python/
# 2. https://www.tutorialspoint.com/python3/
# 3. https://docs.python.org/3.5/
# 4. **http://www.aparat.com/v/z4FgJ**
# 5. https://en.wikipedia.org/wiki/Python_(programming_language)
#
#
# <br><br><br>
# `aliirani74@gmail.com`
